# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Name: Mohamed Said Mahmoud Mohamed Moustafa**
# current occupation: Masters Student

# %%
*I am interested in data science as by pursuing this course, I will not only develop algorithms that I can use in my masters degree, 
in addition, I will have the opportunity to gain a profession in a varied amount of industries.*

# %% [markdown]
# #### This program adds two numbers entered by the user and Display the sum
#
# note: the int in the third line, is to convert the numbers entered by the user to an integer value to be able to the two numbers

# %%
x = input("Please enter the first number: ")
y = input("Please enter the second number: ")

sum = int(x) + int(y)

print("The sum is: ", sum)
# Out:
# Please enter the first number: 1
# Please enter the second number: 2
# The sum is:  3

# %% [markdown]
# ---
#
# |First name|middle name|last name|
# |--------|--------|--------|
# |Mohamed|Said|Moustafa|
#
# ---
#
# <ol>
# <li>Mohamed</li>
# <li>Said</li>
# <li>Moustafa</li>
# </ol>
#
# ---
#
# * Mohamed
# * Said
# * Moustafa
#
# ---
